# %% [markdown]
# # Week 11: Feature Engineering
#
# **Objectives:**
# - Turn raw logs into human features (Fatigue, Hesitation).

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ## 1. Feature Creation

# %%
# Load raw trial logs
# df = pd.read_csv('all_subjects_logs.csv')

# Example Logic
# 1. Micro-level: RT Variability
# rt_std = df.groupby('Subject')['RT'].std()

# 2. Trend-level: Slope (Fatigue)
# slope, intercept, r, p, err = stats.linregress(df['Trial'], df['RT'])

# 3. Post-error slowing
# df['prev_accuracy'] = df['Accuracy'].shift(1)
# pes = df[df['prev_accuracy'] == 0]['RT'].mean() - df[df['prev_accuracy'] == 1]['RT'].mean()
