# %% [markdown]
# # Week 02: Control Flow & Functions
#
# **Instructions:** Fill in the empty code cells. Press `Shift+Enter` to run.

# %% [markdown]
# ## 1. if / elif / else

# %%
score = 75
if score >= 90:
    print('Distinction')
elif ___:  # score >= 60
    print('Pass')
else:
    print('Fail')

# %%
rt = 350
if rt < 200:
    result = 'Too fast'
elif rt < ___:  # normal range upper bound
    result = 'Normal'
else:
    result = '___'
print(result)

# %% [markdown]
# ## 2. for Loops

# %%
for i in range(1, 11):
    print(___)

# %%
rts = [312, 289, 405, 271, 388, 450, 299]
total = 0
for rt in rts:
    total = ___
print(f'Mean RT: {total / len(rts):.1f} ms')

# %%
filtered = [rt for rt in rts if ___]  # keep only rt < 400
print(filtered)

# %% [markdown]
# ## 3. while Loops

# %%
import random
random.seed(42)
heads = 0
flips = 0
while heads < 3:
    flip = random.choice(['H', 'T'])
    flips += 1
    if flip == 'H':
        heads += ___
    else:
        heads = ___
print(f'3 heads after {flips} flips')

# %% [markdown]
# ## 4. Functions

# %%
def mean_rt(rt_list):
    """Return the mean of a list of RTs."""
    total = ___
    return ___

print(mean_rt([312, 289, 405, 271, 388]))

# %%
def classify_rt(rt, threshold=400):
    if rt < threshold:
        return ___
    else:
        return ___

print(classify_rt(350))
print(classify_rt(350, 300))
