# %% [markdown]
# # Week 04 Homework — PsychoPy Basics — Stimuli & Windows
#
# > **Course:** NS5116 Computational Neuroscience — Spring 2026
# > **Week:** 4 of 16 | **Due:** Before Week 05
#
# ---
#
# **Instructions / 說明：**
#
# - 在每題下方的 code cell 中撰寫你的答案(或是將程式碼存為獨立的 `ex1.py` 等檔案)
# - 如果是在 Jupyter 內執行 PsychoPy，請確保視窗有正確關閉 (`win.close()`)
# - 完成後將 homework 資料夾 push 到你的 GitHub repository

# %% [markdown]
# ---
#
# ## 題目一：Dynamic Countdown (Intermediate)
#
# 不要只顯示靜態文字，請製作一個倒數計時。
# 1. 開啟 800x600 的視窗。
# 2. 使用 `core.wait()` 與迴圈 (loop) 依序顯示 "3", "2", "1", 最後顯示 "Welcome to PsychoPy!"。
# 3. 每個數字懶該在畫面上停留 1 秒鐘。
# 4. 在 "Welcome to PsychoPy!" 出現後，等待使用者按下空白鍵 ('space') 後才關閉視窗。

# %%
# === 題目一：請在下方撰寫你的程式碼 ===

# %% [markdown]
# ---
#
# ## 題目二：Continuous Rotation (Advanced)
#
# 撰寫一段程式碼完成以下流程：
# 1. 開啟視窗，並在中央畫一個多邊形 (例如三角形或六邊形)。
# 2. 使用 `while` 迴圈來讓形狀**不斷旋轉**（每個 frame 旋轉 1 度，ori += 1）。
# 3. 在每個 frame 呼叫 `win.flip()`。
# 4. 加入**非阻塞式 (non-blocking)** 的按鍵偵測 (`event.getKeys()`)： 迴圈懶該持續運行與旋轉形狀，直到使用者按下 'escape' 鍵才結束迴圈並關閉視窗。

# %%
# === 題目二：請在下方撰寫你的程式碼 ===

# %% [markdown]
# ---
#
# ## 題目三：Dual Image Manipulation (Advanced)
#
# 請準備**兩張不同的 JPG 圖片**，並完成以下互動：
# 1. 在視窗中**並排**顯示這兩張圖片 (請調整它們的 `pos` 屬性，一左一右)。
# 2. 使用 `while` 迴圈持續偵測按鍵 (non-blocking)。
# 3. 如果按下 'left' 鍵，切換 (toggle) **左**邊圖片的 mask 效果 (例如在 `'gauss'` 與 `None` 之間切換)。
# 4. 如果按下 'right' 鍵，改變 **右**邊圖片的對比 (contrast) (例如在 `1` 與 `-1` 之間切換)。
# 5. 如果按下 'escape' 鍵，則結束迴圈並關閉視窗。
#
# > **Hint**: 使用 `event.getKeys()` 而非 `waitKeys()` 來避免程式卡住。

# %%
# === 題目三：請在下方撰寫你的程式碼 ===

# %% [markdown]
# ---
#
# ## 題目四：Mini-RT Experiment (Advanced)
#
# 使用 `for` 迴圈建立一個包含 **5 個 trial** 的小型實驗區塊 (mini-block)。在每一個 trial 中：
# 1. 顯示注視点 (Fixation cross) **500 ms**。
# 2. 顯示空白畫面，時間為隨機 200 ms 到 500 ms 之間 (請使用 `random.uniform()` 或 `random.randint()` 函數)。
# 3. **隨機**的在畫面的「左側」或「右側」顯示一個目標 (例如 "GO" 字樣)。
# 4. 使用 `core.Clock()` 開始計時，等待使用者按下任意鍵並紀錄 Reaction Time (RT)。
# 5. 5 個 trial 都結束後，計算這 5 次的**平均 RT**，並印出來到 Terminal / Console 中。

# %%
# === 題目四：請在下方撰寫你的程式碼 ===
