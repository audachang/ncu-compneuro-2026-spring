# %% [markdown]
# # Week 01: Python Setup & Basic Syntax
#
# **Instructions:** Fill in the empty code cells. Press `Shift+Enter` to run.

# %% [markdown]
# ## 1. Your First Program

# %%
# Run me!
print('Hello, world!')
print('My name is ___')  # Replace ___ with your name

# %%
# Python Easter egg
import antigravity

# %% [markdown]
# ## 2. Variables and Types

# %%
age = ___        # int: your age
height = ___     # float: your height in meters
name = ___       # str: your name in quotes
is_student = ___ # bool: True or False

print(age, type(age))
# Add prints for height, name, is_student

# %%
# f-string formatting
first = 'Ada'
last = 'Lovelace'
greeting = f'Hello, {first} {last}!'  # fill in
print(greeting)

# %% [markdown]
# ## 3. Arithmetic

# %%
# BMI = weight_kg / (height_m ** 2)
weight = ___
height = ___
bmi = ___
print(f'BMI: {bmi:.2f}')

# %% [markdown]
# ## 4. Comparison Operators

# %%
a, b = 10, 3
print(a == b)
print(a != b)
print(a > b)
print(a >= 10)
