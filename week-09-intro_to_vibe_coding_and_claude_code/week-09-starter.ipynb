# %% [markdown]
# # Week 09: Intro to Vibe Coding & Claude Code
#
# **Instructions:** Fill in the empty code cells. Press `Shift+Enter` to run.

# %% [markdown]
# ## 1. What Is Vibe Coding?

# %%
# Fill in your reflection
vibe_coding = 'Vibe coding is...'
agent_vs_autocomplete = 'Claude Code differs from Copilot because...'
print(vibe_coding)
print(agent_vs_autocomplete)

# %% [markdown]
# ## 2. Claude Code Setup

# %%
# Run these in your TERMINAL (not Jupyter):
#
#   npm install -g @anthropic-ai/claude-code
#   claude --version
#   claude auth login

claude_ready = False  # Change to True after setup
print('Claude Code ready!' if claude_ready else 'Please complete setup in terminal.')

# %% [markdown]
# ## 3. Prompt Patterns

# %%
# Study these prompt patterns
prompts = [
    '1. Create X that does Y.',
    '2. The function crashes on Z. Fix it.',
    '3. Add error handling for edge case W.',
    '4. Write a unit test for this function.',
    '5. Explain what this code does, then suggest an improvement.',
]
for p in prompts:
    print(p)

# %% [markdown]
# ## 4. Project Structure Design

# %%
# Design your final project structure
project_structure = '''
my-final-project/
    README.md
    app.py              <- Streamlit app
    utils/
        data_loader.py
    data/
        .gitkeep
    requirements.txt
    .gitignore
'''
print(project_structure)
# TODO: Use Claude Code to create this structure!
