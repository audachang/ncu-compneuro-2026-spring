# %% [markdown]
# # Week 12: Behavioral Prediction
#
# **Objectives:**
# - Unsupervised Clustering (Personas).
# - Supervised Prediction (Churn).

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## 1. Clustering (Personas)

# %%
# kmeans = KMeans(n_clusters=3)
# df['Persona'] = kmeans.fit_predict(df[['Usage_Hrs', 'Click_Rate']])
# sns.scatterplot(data=df, x='Usage_Hrs', y='Click_Rate', hue='Persona')

# %% [markdown]
# ## 2. Random Forest & Importance

# %%
# clf = RandomForestClassifier()
# clf.fit(X_train, y_train)
# sns.barplot(x=clf.feature_importances_, y=X.columns)
