# %% [markdown]
# # Week 16: Final Project Presentation
#
# **Instructions:** Fill in the empty code cells. Press `Shift+Enter` to run.

# %% [markdown]
# ## 1. Final Submission Check

# %%
import os
checks = [
    ('requirements.txt exists', os.path.exists('requirements.txt')),
    ('README.md exists',        os.path.exists('README.md')),
    ('app.py exists',           os.path.exists('app.py')),
    ('No .env in repo',         not os.path.exists('.env')),
]
for name, ok in checks:
    print(('OK' if ok else 'FIX') + f'  {name}')

# %% [markdown]
# ## 2. Presentation Notes

# %%
notes = '''
# Presentation Notes

## Opening (30 s)
Hi, I am [name]. My app [what it does] because [the problem].

## Data (1 min)
Dataset: [name], from data.gov.tw
Contains: [columns, time range]

## Live Demo (5 min)
1. Landing page
2. Feature 1: ...
3. Feature 2: ...
4. AI feature: ...

## Key Finding (1 min)
The most surprising thing I found was...

## What I Learned (30 s)
From the data: ...
From building: ...
'''
print(notes)

# %% [markdown]
# ## 3. Course Reflection

# %%
prompts = [
    'What was the hardest part of building your app?',
    'What would you add if you had 2 more weeks?',
    'Which Part 1 skill did you use the most in Part 2?',
    'How did Claude Code change how you write code?',
    'What open dataset surprised you most this semester?',
]
for i, q in enumerate(prompts, 1):
    print(f'Q{i}: {q}')
    print(f'A{i}: [your answer]\n')
